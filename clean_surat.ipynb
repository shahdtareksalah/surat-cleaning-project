# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('surat_uncleaned.csv')  


print(df.head())
print(df.info())
null_counts = df.isnull().sum()
print(null_counts)
# Out:
#                                        property_name areaWithType square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
#
#        transaction            status        floor      furnishing  \
# 0     New Property  Poss. by Oct '24  5 out of 10     Unfurnished
# 1     New Property  Poss. by Jan '26  6 out of 14     Unfurnished
# 2           Resale     Ready to Move  5 out of 13  Semi-Furnished
# 3     New Property     Ready to Move  6 out of 14     Unfurnished
# 4  Orchid Fantasia      New Property  Unfurnished               2
#
#         facing                                        description  \
# 0         West  Luxury project with basement parking, Solar ro...
# 1  South -West  2 And 3 BHK Luxurious Flat for Sell In New Alt...
# 2         East  This affordable 2 BHK flat is situated along a...
# 3         East  2 BHK Flat For sell IN Jahangirabad Prime Loca...
# 4            2  Multistorey Apartment for Sale in Palanpur, Su...
#
#      price_per_sqft       price
# 0  ₹2,891 per sqft   ₹33.8 Lac
# 1  ₹3,551 per sqft   ₹45.4 Lac
# 2  ₹3,800 per sqft   ₹44.6 Lac
# 3  ₹3,966 per sqft     ₹47 Lac
# 4  ₹3,600 per sqft     ₹45 Lac
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   property_name   4525 non-null   object
#  1   areaWithType    4525 non-null   object
#  2   square_feet     4525 non-null   object
#  3   transaction     4421 non-null   object
#  4   status          4524 non-null   object
#  5   floor           4480 non-null   object
#  6   furnishing      4185 non-null   object
#  7   facing          3936 non-null   object
#  8   description     3154 non-null   object
#  9   price_per_sqft  4157 non-null   object
#  10  price           4525 non-null   object
# dtypes: object(11)
# memory usage: 389.0+ KB
# None
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        104
# status               1
# floor               45
# furnishing         340
# facing             589
# description       1371
# price_per_sqft     368
# price                0
# dtype: int64

# %%
df.replace(['-', 'NA', 'N/A', '?', 'xx', '--', 'nan'], np.nan, inplace=True)


def clean_number(col):
    return (
        df[col]
        .astype(str)
        .str.replace('[^0-9.]', '', regex=True) 
        .str.strip()
    )

num_cols = ['square_feet', 'price_per_sqft', 'price']

for col in num_cols:
    df[col] = clean_number(col)
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df['floor_cleaned'] = (
    df['floor']
    .astype(str)
    .str.extract('(\d+)') 
    .astype(float)
)
df['floor_cleaned'] = df['floor_cleaned'].replace({
    'Basement': 0,
    'basement': 0,
    'Basement Floor': 0,
    'Ground': 1,
    'Ground Floor': 1,
    'ground': 1,
})

# %%
valid_furnishing = ['Unfurnished', 'Semi-Furnished', 'Furnished']
valid_facings = [
    'East', 'West', 'North', 'South',
    'North-East', 'South-East', 'North-West', 'South-West',
    'Main Road', 'Garden Facing'
]
valid_transactions = ['New Property', 'Resale']
valid_status = ['Ready to Move', 'Under Construction']

df['transaction'] = df['transaction'].where(df['transaction'].isin(valid_transactions), np.nan)

def clean_row(row):
    f = str(row['furnishing']).strip()
    fa = str(row['facing']).strip()

    if f not in valid_furnishing:
        if f in valid_facings:
            row['facing'] = f
            row['furnishing'] = None
        elif f.replace('.', '', 1).isdigit() or len(f) < 3:
            row['furnishing'] = None
        elif ' ' in f or (f.isalpha() and f not in valid_furnishing):
            row['furnishing'] = None

    if fa not in valid_facings:
        if fa in valid_furnishing:
            row['furnishing'] = fa
            row['facing'] = None
        elif fa.replace('.', '', 1).isdigit() or len(fa) < 3:
            row['facing'] = None
        elif ' ' in fa or (fa.isalpha() and fa not in valid_facings):
            row['facing'] = None

    return row

df = df.apply(clean_row, axis=1)

def clean_status(value):
    value = str(value).strip()
    if value in valid_status:
        return value
    elif value.startswith("Poss. by"):
        return value
    else:
        return np.nan

df['status'] = df['status'].apply(clean_status)

df.reset_index(drop=True, inplace=True)
df.loc[df['furnishing'] == 'Garden/Park', ['furnishing', 'facing']] = [np.nan, 'Garden Facing']
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# property_name        0
# areaWithType         0
# square_feet          6
# transaction        842
# status             330
# floor               45
# furnishing        1255
# facing            2560
# description       1371
# price_per_sqft     368
# price              173
# floor_cleaned      839
# dtype: int64

# %%
cat_cols = ['transaction', 'status', 'furnishing', 'facing']
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

df.dropna(subset=['price'], inplace=True)
df.dropna(subset=['square_feet'], inplace=True)

df['price_per_sqft'] = df['price_per_sqft'].fillna(df['price_per_sqft'].median())
df['floor_cleaned'] = df['floor_cleaned'].fillna(df['floor_cleaned'].median())

df.drop(columns=['description'], inplace=True, errors='ignore')
df.drop(columns=['floor'], inplace=True, errors='ignore')
df['floor_cleaned'] = df['floor_cleaned'].astype(int)
print(df['floor_cleaned'].unique())
# Out:
# [ 5  6  7  3  1  4  2  9 12 10 13 14  8 16 11 59 15 18 20 17 19]

# %%
print(df['facing'].head(50))
print(df.value_counts().sum())
null_counts = df.isnull().sum()
print(null_counts)
print(df.describe())
print(df['square_feet'].unique()[:20])
df.rename(columns={
    'price': 'price (₹ Lac)',
    'price_per_sqft': 'price_per_sqft (₹)'
}, inplace=True)
print(df.info())
# Out:
# 0            West
# 1            East
# 2            East
# 3            East
# 4            East
# 5            East
# 6            East
# 7            East
# 8            East
# 9            East
# 10           East
# 11           East
# 12           East
# 13           East
# 14           East
# 15           East
# 16           East
# 17           East
# 18           East
# 19           East
# 20           East
# 21           West
# 22           East
# 23           West
# 24           East
# 25           East
# 26           East
# 27           East
# 28           East
# 29           East
# 30           East
# 31           East
# 32           East
# 33           East
# 34           East
# 35           East
# 36           East
# 37    Garden/Park
# 38           East
# 39           East
# 40           East
# 41      Main Road
# 42           East
# 43           East
# 44           East
# 45           East
# 46           East
# 47           East
# 48           East
# 49           East
# Name: facing, dtype: object
# 4346
# property_name     0
# areaWithType      0
# square_feet       0
# transaction       0
# status            0
# furnishing        0
# facing            0
# price_per_sqft    0
# price             0
# floor_cleaned     0
# dtype: int64
#          square_feet  price_per_sqft        price  floor_cleaned
# count    4346.000000    4.346000e+03  4346.000000    4346.000000
# mean     2116.257478    9.270390e+03    34.059883       5.197193
# std     11259.962059    1.897936e+05    31.148656       2.971441
# min         3.000000    1.000000e+00     1.000000       1.000000
# 25%       800.000000    3.724250e+03     2.320000       3.000000
# 50%      1275.000000    4.700000e+03    30.000000       5.000000
# 75%      2000.000000    6.121750e+03    58.500000       7.000000
# max    390045.000000    1.250000e+07   534.440000      59.000000
# [ 644. 1278. 1173.  700. 1250. 1265. 1404. 1180.  720.  748.  480. 1650.
#   847. 1511.  850.  180.  800. 1000.  731.  816.]
# <class 'pandas.core.frame.DataFrame'>
# Index: 4346 entries, 0 to 4517
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   property_name       4346 non-null   object
#  1   areaWithType        4346 non-null   object
#  2   square_feet         4346 non-null   float64
#  3   transaction         4346 non-null   object
#  4   status              4346 non-null   object
#  5   furnishing          4346 non-null   object
#  6   facing              4346 non-null   object
#  7   price_per_sqft (₹)  4346 non-null   float64
#  8   price (₹ Lac)       4346 non-null   float64
#  9   floor_cleaned       4346 non-null   int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 373.5+ KB
# None

# %%
# le = LabelEncoder()
# df['furnishing_encoded'] = le.fit_transform(df['furnishing'])

# df = pd.get_dummies(df, columns=['transaction'], drop_first=True)

# print(df.head())

# %%
df = df.drop_duplicates()
df.info()
print(df.head(50))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4212 entries, 0 to 4517
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   property_name       4212 non-null   object
#  1   areaWithType        4212 non-null   object
#  2   square_feet         4212 non-null   float64
#  3   transaction         4212 non-null   object
#  4   status              4212 non-null   object
#  5   furnishing          4212 non-null   object
#  6   facing              4212 non-null   object
#  7   price_per_sqft (₹)  4212 non-null   float64
#  8   price (₹ Lac)       4212 non-null   float64
#  9   floor_cleaned       4212 non-null   int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 362.0+ KB
#                                         property_name areaWithType  \
# 0           2 BHK Apartment for Sale in Dindoli Surat  Carpet Area
# 1            2 BHK Apartment for Sale in Althan Surat   Super Area
# 2           2 BHK Apartment for Sale in Pal Gam Surat   Super Area
# 3      2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 4   2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area
# 5   2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area
# 6               3 BHK Villa for Sale in Dindoli Surat  Carpet Area
# 7                 Office Space for Sale in Vesu Surat  Carpet Area
# 8   2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area
# 9          2 BHK Apartment for Sale in Palanpur Surat  Carpet Area
# 10     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 11                 1 BHK  House for Sale in Kim Surat  Carpet Area
# 12   2 BHK Apartment for Sale in NavYug College Surat  Carpet Area
# 13           2 BHK Apartment for Sale in Adajan Surat   Super Area
# 14          3 BHK Apartment for Sale in Dindoli Surat   Super Area
# 15      2 BHK Apartment for Sale in Bhatar Road Surat  Carpet Area
# 16              Shop for Sale in Moti Begumwadi Surat  Carpet Area
# 17             Office Space for Sale in Nanpura Surat   Super Area
# 18    3 BHK Apartment for Sale in Mota Varachha Surat  Carpet Area
# 19         1 BHK Apartment for Sale in Ramnagar Surat  Carpet Area
# 20    Office Space for Sale in Belgium Tower Ring ...  Carpet Area
# 21       2 BHK Builder Floor for Sale in Amroli Surat  Carpet Area
# 22  2 BHK Apartment for Sale in Palan Pur Patiya S...   Super Area
# 23             1 BHK  House for Sale in Palsana Surat  Carpet Area
# 24               Shop for Sale in Ghod Dod Road Surat  Carpet Area
# 25     3 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 26         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area
# 27         2 BHK Apartment for Sale in Palanpur Surat   Super Area
# 28        3 BHK Villa for Sale in Masma Village Surat  Carpet Area
# 29  2 BHK Apartment for Sale in Shivalik Height Surat   Super Area
# 30           2 BHK Apartment for Sale in Althan Surat   Super Area
# 31         2 BHK Apartment for Sale in Palanpur Surat   Super Area
# 32          2 BHK Apartment for Sale in Bamroli Surat   Super Area
# 33     2 BHK Apartment for Sale in Jahangirabad Surat   Super Area
# 34         2 BHK Apartment for Sale in Godadara Surat  Carpet Area
# 35         3 BHK Apartment for Sale in Palanpur Surat   Super Area
# 36     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 37               Plot/Land for Sale in Bhatpore Surat    Plot Area
# 38                     Shop for Sale in Kosamba Surat  Carpet Area
# 39               Office Space for Sale in Udhna Surat  Carpet Area
# 40                Plot/Land for Sale in Narthan Surat    Plot Area
# 41     1 BHK Apartment for Sale in Jahangirabad Surat   Super Area
# 42         2 BHK Apartment for Sale in Palanpur Surat   Super Area
# 43                Office Space for Sale in Vesu Surat   Super Area
# 44     2 BHK Apartment for Sale in Jahangirabad Surat   Super Area
# 45    3 BHK Apartment for Sale in Jahangir Pura Surat   Super Area
# 46     3 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 47         3 BHK Apartment for Sale in Palanpur Surat   Super Area
# 48      Shop for Sale in Rajhnsh platinum plaza Surat   Super Area
# 49          2 BHK Apartment for Sale in Bamroli Surat  Carpet Area
#
#     square_feet   transaction            status      furnishing       facing  \
# 0         644.0  New Property  Poss. by Oct '24     Unfurnished         West
# 1        1278.0  New Property  Poss. by Jan '26     Unfurnished         East
# 2        1173.0        Resale     Ready to Move  Semi-Furnished         East
# 3         700.0  New Property     Ready to Move     Unfurnished         East
# 4        1250.0        Resale     Ready to Move     Unfurnished         East
# 5        1265.0        Resale  Poss. by Dec '25     Unfurnished         East
# 6        1404.0        Resale  Poss. by Jun '24     Unfurnished         East
# 7         700.0  New Property  Poss. by Sep '25     Unfurnished         East
# 8        1180.0        Resale     Ready to Move     Unfurnished         East
# 9         720.0  New Property  Poss. by Dec '25     Unfurnished         East
# 10        748.0  New Property  Poss. by Dec '25     Unfurnished         East
# 11        480.0        Resale     Ready to Move     Unfurnished         East
# 12       1650.0        Resale     Ready to Move     Unfurnished         East
# 13        847.0        Resale     Ready to Move       Furnished         East
# 14       1511.0  New Property  Poss. by Feb '26     Unfurnished         East
# 15        850.0        Resale     Ready to Move       Furnished         East
# 16        180.0        Resale     Ready to Move     Unfurnished         East
# 17        800.0        Resale     Ready to Move     Unfurnished         East
# 18       1000.0  New Property     Ready to Move       Furnished         East
# 19        731.0        Resale     Ready to Move     Unfurnished         East
# 20        816.0        Resale     Ready to Move     Unfurnished         East
# 21        950.0        Resale     Ready to Move     Unfurnished         West
# 22       1150.0        Resale     Ready to Move     Unfurnished         East
# 23        432.0  New Property     Ready to Move     Unfurnished         West
# 24        350.0        Resale     Ready to Move     Unfurnished         East
# 25        910.0        Resale     Ready to Move     Unfurnished         East
# 26        650.0        Resale     Ready to Move     Unfurnished         East
# 27       1250.0  New Property     Ready to Move     Unfurnished         East
# 28       1480.0        Resale  Poss. by Jul '24     Unfurnished         East
# 29       1105.0        Resale     Ready to Move     Unfurnished         East
# 30       1305.0  New Property  Poss. by Dec '26     Unfurnished         East
# 31       1290.0        Resale     Ready to Move       Furnished         East
# 32        975.0  New Property  Poss. by Apr '25     Unfurnished         East
# 33       1250.0  New Property     Ready to Move     Unfurnished         East
# 34        725.0  New Property  Poss. by Jan '25     Unfurnished         East
# 35       1558.0        Resale     Ready to Move     Unfurnished         East
# 36        727.0  New Property     Ready to Move     Unfurnished         East
# 37        120.0        Resale     Ready to Move     Unfurnished  Garden/Park
# 38        425.0        Resale     Ready to Move     Unfurnished         East
# 39        396.0        Resale     Ready to Move     Unfurnished         East
# 40       1055.0        Resale     Ready to Move     Unfurnished         East
# 41        735.0        Resale     Ready to Move     Unfurnished    Main Road
# 42       1326.0        Resale     Ready to Move     Unfurnished         East
# 43        510.0  New Property  Poss. by Dec '25     Unfurnished         East
# 44       1178.0        Resale     Ready to Move     Unfurnished         East
# 45       1900.0        Resale     Ready to Move     Unfurnished         East
# 46         80.0        Resale     Ready to Move     Unfurnished         East
# 47       1600.0        Resale     Ready to Move     Unfurnished         East
# 48        445.0        Resale     Ready to Move     Unfurnished         East
# 49        680.0  New Property  Poss. by Jan '26     Unfurnished         East
#
#     price_per_sqft (₹)  price (₹ Lac)  floor_cleaned
# 0               2891.0           33.8              5
# 1               3551.0           45.4              6
# 2               3800.0           44.6              5
# 3               3966.0           47.0              6
# 4               3600.0           45.0              5
# 5               3411.0           43.2              5
# 6               4700.0           42.1              5
# 7               3392.0           44.1              7
# 8               3751.0           44.3              5
# 9               3200.0           40.0              3
# 10              3235.0           44.0              6
# 11              2315.0           12.5              1
# 12              3125.0           50.0              7
# 13              5903.0           50.0              1
# 14              2368.0           35.8              5
# 15              4700.0           45.0              4
# 16             14728.0           26.5              3
# 17              5250.0           42.0              2
# 18              3185.0           43.0              3
# 19              2736.0           20.0              2
# 20              4534.0           37.0              3
# 21              2829.0           29.0              5
# 22              3304.0           38.0              5
# 23              3009.0           13.0              1
# 24             12857.0           45.0              7
# 25              2857.0           40.0              1
# 26              4150.0           46.5              5
# 27              3325.0           41.6              7
# 28              2264.0           33.5              5
# 29              3842.0           42.5              9
# 30              3678.0           48.0              5
# 31              3488.0           45.0              5
# 32              3282.0           32.0              6
# 33              2800.0           35.0              7
# 34              3500.0           46.2              7
# 35              3017.0           47.0              1
# 36              3075.0           38.5              7
# 37             35000.0           42.0              5
# 38              4706.0           20.0              1
# 39              5808.0           23.0              2
# 40              2275.0           24.0              5
# 41              3810.0           28.0             12
# 42              3771.0           50.0              9
# 43              7000.0           35.7              3
# 44              3099.0           36.5             10
# 45              2632.0           50.0              7
# 46              4700.0           36.0              2
# 47              2724.0           43.6              3
# 48              5618.0           25.0              1
# 49              3747.0           46.5              6

# %%
df.to_csv('clean_data.csv', index=False)

# %%
# 1. توزيع الأسعار (Price Distribution)
plt.figure(figsize=(10, 6))
sns.histplot(df['price (₹ Lac)'], kde=True, color='skyblue')
plt.title('(Distribution of Prices)')
plt.xlabel('Price (₹ Lac)')
plt.ylabel('Count')
plt.show()

# 2. توزيع المساحات (Square Feet Distribution)
# سنقوم بتحديد حد أقصى للمساحة في الرسم لأن القيم الشاذة قد تخفي التفاصيل
plt.figure(figsize=(10, 6))
sns.histplot(df[df['square_feet'] < 5000]['square_feet'], kde=True, color='salmon')
plt.title('Square Feet Distribution')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='square_feet', y='price_per_sqft (₹)')
plt.title("Price per sqft vs Area")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='square_feet', y='price (₹ Lac)', hue='furnishing')
plt.title("Price vs Area")
plt.xlabel("Square Feet")
plt.ylabel("Price (Lac ₹)")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
cat_cols = ['transaction', 'status', 'furnishing', 'facing']
plt.figure(figsize=(14,10))

for i, col in enumerate(cat_cols, 1):
    plt.subplot(2, 2, i)  # صفين، عمودين
    sns.countplot(data=df, x=col)
    plt.title(f"Count of {col}")
    plt.xticks(rotation=45)
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='floor_cleaned', y='price (₹ Lac)')
plt.title("Price vs Floor Level")
plt.xlabel("Floor")
plt.ylabel("Price (Lac ₹)")
plt.show()

# %%
price_by_furnishing = df.groupby('furnishing')['price (₹ Lac)'].mean()
print("Average Price by Furnishing:")
print(price_by_furnishing)

area_by_transaction = df.groupby('transaction')['square_feet'].mean()
print("\nAverage Area by Transaction:")
print(area_by_transaction)

count_by_facing = df.groupby('facing').size()
print("\nCount of Properties by Facing:")
print(count_by_facing)

price_by_floor = df.groupby('floor_cleaned')['price (₹ Lac)'].mean()
print("\nAverage Price by Floor:")
print(price_by_floor)

pps_by_status = df.groupby('status')['price_per_sqft (₹)'].mean()
print("\nAvg Price Per Sqft by Status:")
print(pps_by_status)
# Out:
# Average Price by Furnishing:
# furnishing
# Furnished         42.964614
# Semi-Furnished    39.293105
# Unfurnished       32.621560
# Name: price (₹ Lac), dtype: float64
#
# Average Area by Transaction:
# transaction
# New Property    2238.164345
# Resale          2087.268372
# Name: square_feet, dtype: float64
#
# Count of Properties by Facing:
# facing
# East             3903
# Garden Facing       2
# Garden/Park        26
# Main Road          58
# North              95
# South              35
# West               93
# dtype: int64
#
# Average Price by Floor:
# floor_cleaned
# 1     33.097571
# 2     34.601603
# 3     35.035697
# 4     33.148243
# 5     31.723361
# 6     39.528311
# 7     36.199695
# 8     37.271154
# 9     37.450409
# 10    32.312124
# 11    42.352297
# 12    36.866275
# 13    39.447222
# 14    49.200000
# 15    31.070000
# 16    15.480000
# 17     5.648000
# 18     9.176667
# 19     3.265000
# 20    28.850000
# 59    29.000000
# Name: price (₹ Lac), dtype: float64
#
# Avg Price Per Sqft by Status:
# status
# Poss. by Apr '25     4987.304348
# Poss. by Apr '26     4703.615385
# Poss. by Apr '27     6550.000000
# Poss. by Aug '24     4875.075472
# Poss. by Aug '25     5102.500000
# Poss. by Aug '26     5585.500000
# Poss. by Dec '24     5248.614865
# Poss. by Dec '25     5010.875000
# Poss. by Dec '26     5437.500000
# Poss. by Dec '27     6273.333333
# Poss. by Dec '28     7200.000000
# Poss. by Feb '25     5015.090909
# Poss. by Feb '26     4426.842105
# Poss. by Jan '25     5322.111111
# Poss. by Jan '26     4913.720000
# Poss. by Jan '27     5863.333333
# Poss. by Jul '24     5923.051948
# Poss. by Jul '25     5531.400000
# Poss. by Jul '26     6132.666667
# Poss. by Jul '27     5703.000000
# Poss. by Jun '24     5261.558140
# Poss. by Jun '25     4985.380952
# Poss. by Jun '26     5668.875000
# Poss. by Jun '27     7541.500000
# Poss. by Mar '25     5308.500000
# Poss. by Mar '26     4660.384615
# Poss. by Mar '27     7194.000000
# Poss. by Mar '28     7002.000000
# Poss. by May '25     6098.475000
# Poss. by May '26     5242.642857
# Poss. by May '27     5812.000000
# Poss. by Nov '24     4824.038462
# Poss. by Nov '25     5196.153846
# Poss. by Nov '26     6309.000000
# Poss. by Nov '28     6200.000000
# Poss. by Oct '24     4887.027778
# Poss. by Oct '25     5008.040000
# Poss. by Oct '26     5428.222222
# Poss. by Sep '24     4981.206897
# Poss. by Sep '25     5079.250000
# Poss. by Sep '26     4832.333333
# Ready to Move       10608.533695
# Name: price_per_sqft (₹), dtype: float64
